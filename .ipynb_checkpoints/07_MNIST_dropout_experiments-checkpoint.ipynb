# %% [markdown]
# ### mmm

# %%
import numpy as np

from keras.datasets import mnist
from keras import models
from keras import layers
from keras.utils import to_categorical
import matplotlib.pyplot as plt
# Out:
# Using TensorFlow backend.

# %%
# Download the MNIST dataset
(train_images, train_labels), (test_images, test_labels) = mnist.load_data()

# %%
# The training data has 60000 samples (28x28 images)
print train_images.shape
# Each image has a label (0 to 9)
print len(train_labels)
train_labels
# Out:
# (60000, 28, 28)
# 60000
# array([5, 0, 4, ..., 5, 6, 8], dtype=uint8)

# %%
# The test data has 10000 samples (28x28 images)
print test_images.shape
# Each image has a label (0 to 9)
print len(test_labels)
test_labels
# Out:
# (10000, 28, 28)
# 10000
# array([7, 2, 1, ..., 4, 5, 6], dtype=uint8)

# %%
# Reshape the samples (each sample has 28*28 'features') and normalize between 0-1
train_images = train_images.reshape((60000, 28 * 28))
train_images = train_images.astype('float32') / 255
test_images = test_images.reshape((10000, 28 * 28))
test_images = test_images.astype('float32') / 255

train_labels = to_categorical(train_labels)
test_labels = to_categorical(test_labels)

val_images = train_images[:15000,:]
val_labels = train_labels[:15000,:]

train_images = train_images[15000:,:]
train_labels = train_labels[15000:,:]

# %%
def create_MNIST_model(dropout_list):
    
    model = models.Sequential()
    model.add(layers.Dense(128, activation='relu', input_shape=(28 * 28,)))
    model.add(layers.Dropout(dropout_list[0]))
    model.add(layers.Dense(256, activation='relu'))
    model.add(layers.Dropout(dropout_list[1]))
    model.add(layers.Dense(10, activation='softmax'))

    model.compile(optimizer='rmsprop',loss='categorical_crossentropy',metrics=['accuracy'])
    history = model.fit(train_images, train_labels, epochs=25, batch_size=128, validation_data=(val_images, val_labels))
    return model, history

# %%
[model1, history1] = create_MNIST_model([0,0])
# Out:
# Train on 45000 samples, validate on 15000 samples
# Epoch 1/25
# 45000/45000 [==============================] - 2s 48us/step - loss: 0.3281 - acc: 0.9051 - val_loss: 0.1749 - val_acc: 0.9489
# Epoch 2/25
# 45000/45000 [==============================] - 2s 38us/step - loss: 0.1397 - acc: 0.9576 - val_loss: 0.1367 - val_acc: 0.9587
# Epoch 3/25
# 45000/45000 [==============================] - 2s 39us/step - loss: 0.0957 - acc: 0.9707 - val_loss: 0.1191 - val_acc: 0.9637
# Epoch 4/25
# 45000/45000 [==============================] - 2s 39us/step - loss: 0.0723 - acc: 0.9771 - val_loss: 0.1230 - val_acc: 0.9628
# Epoch 5/25
# 45000/45000 [==============================] - 2s 40us/step - loss: 0.0548 - acc: 0.9826 - val_loss: 0.1038 - val_acc: 0.9697
# Epoch 6/25
# 45000/45000 [==============================] - 2s 40us/step - loss: 0.0438 - acc: 0.9863 - val_loss: 0.0978 - val_acc: 0.9725
# Epoch 7/25
# ...

# %%
[model2, history2] = create_MNIST_model([0.5,0])
# Out:
# Train on 45000 samples, validate on 15000 samples
# Epoch 1/25
# 45000/45000 [==============================] - 3s 60us/step - loss: 0.4854 - acc: 0.8526 - val_loss: 0.2195 - val_acc: 0.9355
# Epoch 2/25
# 45000/45000 [==============================] - 2s 41us/step - loss: 0.2558 - acc: 0.9233 - val_loss: 0.1586 - val_acc: 0.9522
# Epoch 3/25
# 45000/45000 [==============================] - 2s 42us/step - loss: 0.2096 - acc: 0.9365 - val_loss: 0.1396 - val_acc: 0.9596
# Epoch 4/25
# 45000/45000 [==============================] - 2s 42us/step - loss: 0.1822 - acc: 0.9451 - val_loss: 0.1314 - val_acc: 0.9631
# Epoch 5/25
# 45000/45000 [==============================] - 2s 43us/step - loss: 0.1663 - acc: 0.9500 - val_loss: 0.1208 - val_acc: 0.9657
# Epoch 6/25
# 45000/45000 [==============================] - 3s 60us/step - loss: 0.1574 - acc: 0.9511 - val_loss: 0.1115 - val_acc: 0.9675
# Epoch 7/25
# ...

# %%
[model3, history3] = create_MNIST_model([0,0.5])
# Out:
# Train on 45000 samples, validate on 15000 samples
# Epoch 1/25
# 45000/45000 [==============================] - 2s 54us/step - loss: 0.3859 - acc: 0.8846 - val_loss: 0.1826 - val_acc: 0.9471
# Epoch 2/25
# 45000/45000 [==============================] - 2s 41us/step - loss: 0.1652 - acc: 0.9508 - val_loss: 0.1427 - val_acc: 0.9585
# Epoch 3/25
# 45000/45000 [==============================] - 2s 42us/step - loss: 0.1182 - acc: 0.9646 - val_loss: 0.1222 - val_acc: 0.9651
# Epoch 4/25
# 45000/45000 [==============================] - 2s 42us/step - loss: 0.0924 - acc: 0.9726 - val_loss: 0.1046 - val_acc: 0.9702
# Epoch 5/25
# 45000/45000 [==============================] - 2s 42us/step - loss: 0.0748 - acc: 0.9769 - val_loss: 0.0949 - val_acc: 0.9744
# Epoch 6/25
# 45000/45000 [==============================] - 2s 42us/step - loss: 0.0604 - acc: 0.9818 - val_loss: 0.1041 - val_acc: 0.9712
# Epoch 7/25
# ...

# %%
[model4, history4] = create_MNIST_model([0.5,0.5])
# Out:
# Train on 45000 samples, validate on 15000 samples
# Epoch 1/25
# 45000/45000 [==============================] - 3s 66us/step - loss: 0.5967 - acc: 0.8126 - val_loss: 0.2339 - val_acc: 0.9307
# Epoch 2/25
# 45000/45000 [==============================] - 2s 55us/step - loss: 0.2972 - acc: 0.9123 - val_loss: 0.1781 - val_acc: 0.9491
# Epoch 3/25
# 45000/45000 [==============================] - 2s 45us/step - loss: 0.2437 - acc: 0.9293 - val_loss: 0.1561 - val_acc: 0.9543
# Epoch 4/25
# 45000/45000 [==============================] - 2s 45us/step - loss: 0.2241 - acc: 0.9354 - val_loss: 0.1416 - val_acc: 0.9595
# Epoch 5/25
# 45000/45000 [==============================] - 2s 43us/step - loss: 0.2099 - acc: 0.9395 - val_loss: 0.1389 - val_acc: 0.9612
# Epoch 6/25
# 45000/45000 [==============================] - 2s 42us/step - loss: 0.1927 - acc: 0.9450 - val_loss: 0.1302 - val_acc: 0.9655
# Epoch 7/25
# ...

# %%
epochs = range(1, len(history1.history['acc']) + 1)

plt.plot(epochs, history1.history['loss'], 'b', linestyle='-', label='Baseline')
plt.plot(epochs, history1.history['val_loss'], 'b', linestyle='--')

plt.plot(epochs, history2.history['loss'], 'r', linestyle='-', label='Dropout layer 1')
plt.plot(epochs, history2.history['val_loss'], 'r', linestyle='--')

plt.plot(epochs, history3.history['loss'], 'g', linestyle='-', label='Dropout layer 2')
plt.plot(epochs, history3.history['val_loss'], 'g', linestyle='--')

plt.plot(epochs, history4.history['loss'], 'y', linestyle='-', label='Dropout both layers')
plt.plot(epochs, history4.history['val_loss'], 'y', linestyle='--')

plt.title('Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

# %%
[model5, history5] = create_MNIST_model([0.3,0.3])
# Out:
# Train on 45000 samples, validate on 15000 samples
# Epoch 1/25
# 45000/45000 [==============================] - 3s 58us/step - loss: 0.4407 - acc: 0.8668 - val_loss: 0.2053 - val_acc: 0.9375
# Epoch 2/25
# 45000/45000 [==============================] - 2s 44us/step - loss: 0.2104 - acc: 0.9362 - val_loss: 0.1597 - val_acc: 0.9543
# Epoch 3/25
# 45000/45000 [==============================] - 2s 45us/step - loss: 0.1646 - acc: 0.9505 - val_loss: 0.1290 - val_acc: 0.9627
# Epoch 4/25
# 45000/45000 [==============================] - 2s 44us/step - loss: 0.1380 - acc: 0.9579 - val_loss: 0.1170 - val_acc: 0.9668
# Epoch 5/25
# 45000/45000 [==============================] - 2s 44us/step - loss: 0.1214 - acc: 0.9643 - val_loss: 0.1095 - val_acc: 0.9692
# Epoch 6/25
# 45000/45000 [==============================] - 2s 45us/step - loss: 0.1102 - acc: 0.9670 - val_loss: 0.1022 - val_acc: 0.9714
# Epoch 7/25
# ...

# %%
[model6, history09] = create_MNIST_model([0.9,0.9])
# Out:
# Train on 45000 samples, validate on 15000 samples
# Epoch 1/25
# 45000/45000 [==============================] - 4s 87us/step - loss: 2.1745 - acc: 0.1979 - val_loss: 1.7721 - val_acc: 0.5784
# Epoch 2/25
# 45000/45000 [==============================] - 2s 52us/step - loss: 1.8772 - acc: 0.3057 - val_loss: 1.4678 - val_acc: 0.6192
# Epoch 3/25
# 45000/45000 [==============================] - 2s 52us/step - loss: 1.7422 - acc: 0.3463 - val_loss: 1.2863 - val_acc: 0.6347
# Epoch 4/25
# 45000/45000 [==============================] - 2s 51us/step - loss: 1.6652 - acc: 0.3703 - val_loss: 1.1907 - val_acc: 0.6528
# Epoch 5/25
# 45000/45000 [==============================] - 2s 51us/step - loss: 1.6342 - acc: 0.3815 - val_loss: 1.1796 - val_acc: 0.6578
# Epoch 6/25
# 45000/45000 [==============================] - 2s 52us/step - loss: 1.6233 - acc: 0.3902 - val_loss: 1.1605 - val_acc: 0.6512
# Epoch 7/25
# ...

# %%
# Compare the 3 models

epochs = range(1, len(history1.history['acc']) + 1)

plt.plot(epochs, history00.history['loss'], 'b', linestyle='-', label='0')
plt.plot(epochs, history01.history['loss'], 'r', linestyle='-', label='0.1')
plt.plot(epochs, history02.history['loss'], 'g', linestyle='-', label='0.2')
plt.plot(epochs, history03.history['loss'], 'y', linestyle='-', label='0.3')
plt.plot(epochs, history04.history['loss'], 'm', linestyle='-', label='0.4')
plt.plot(epochs, history05.history['loss'], 'b', linestyle='-.', label='0.5')
plt.plot(epochs, history06.history['loss'], 'r', linestyle='-.', label='0.6')
plt.plot(epochs, history07.history['loss'], 'g', linestyle='-.', label='0.7')
plt.plot(epochs, history08.history['loss'], 'y', linestyle='-.', label='0.8')
plt.plot(epochs, history09.history['loss'], 'm', linestyle='-.', label='0.9')

plt.title('Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

# %%
plt.figure(figsize=(13,10))

plt.subplot(5,2,1)
epochs = range(1, len(history00.history['acc']) + 1)
plt.plot(epochs, history00.history['loss'], 'b', linestyle='-', label='Standard')
plt.plot(epochs, history00.history['val_loss'], 'b', linestyle='--')
plt.xlabel('Epochs')
plt.legend()

plt.subplot(5,2,2)
epochs = range(1, len(history01.history['acc']) + 1)
plt.plot(epochs, history01.history['loss'], 'b', linestyle='-', label='0.1')
plt.plot(epochs, history01.history['val_loss'], 'b', linestyle='--')
plt.xlabel('Epochs')
plt.legend()

plt.subplot(5,2,3)
epochs = range(1, len(history02.history['acc']) + 1)
plt.plot(epochs, history02.history['loss'], 'b', linestyle='-', label='0.2')
plt.plot(epochs, history02.history['val_loss'], 'b', linestyle='--')
plt.xlabel('Epochs')
plt.legend()

plt.subplot(5,2,4)
epochs = range(1, len(history03.history['acc']) + 1)
plt.plot(epochs, history03.history['loss'], 'b', linestyle='-', label='0.3')
plt.plot(epochs, history03.history['val_loss'], 'b', linestyle='--')
plt.xlabel('Epochs')
plt.legend()

plt.subplot(5,2,5)
epochs = range(1, len(history04.history['acc']) + 1)
plt.plot(epochs, history04.history['loss'], 'b', linestyle='-', label='0.4')
plt.plot(epochs, history04.history['val_loss'], 'b', linestyle='--')
plt.xlabel('Epochs')
plt.legend()

plt.subplot(5,2,6)
epochs = range(1, len(history05.history['acc']) + 1)
plt.plot(epochs, history05.history['loss'], 'b', linestyle='-', label='0.5')
plt.plot(epochs, history05.history['val_loss'], 'b', linestyle='--')
plt.xlabel('Epochs')
plt.legend()

plt.subplot(5,2,7)
epochs = range(1, len(history06.history['acc']) + 1)
plt.plot(epochs, history06.history['loss'], 'b', linestyle='-', label='0.6')
plt.plot(epochs, history06.history['val_loss'], 'b', linestyle='--')
plt.xlabel('Epochs')
plt.legend()

plt.subplot(5,2,8)
epochs = range(1, len(history07.history['acc']) + 1)
plt.plot(epochs, history07.history['loss'], 'b', linestyle='-', label='0.7')
plt.plot(epochs, history07.history['val_loss'], 'b', linestyle='--')
plt.xlabel('Epochs')
plt.legend()

plt.subplot(5,2,9)
epochs = range(1, len(history08.history['acc']) + 1)
plt.plot(epochs, history08.history['loss'], 'b', linestyle='-', label='0.8')
plt.plot(epochs, history08.history['val_loss'], 'b', linestyle='--')
plt.xlabel('Epochs')
plt.legend()

plt.subplot(5,2,10)
epochs = range(1, len(history09.history['acc']) + 1)
plt.plot(epochs, history09.history['loss'], 'b', linestyle='-', label='0.9')
plt.plot(epochs, history09.history['val_loss'], 'b', linestyle='--')
plt.xlabel('Epochs')
plt.legend()

# %%
# Plot the training loss

epochs = range(1, len(history1.history['acc']) + 1)

plt.plot(epochs, history1.history['loss'], 'b', linestyle='-', label='Standard')
plt.plot(epochs, history1.history['val_loss'], 'b', linestyle='--')

plt.title('Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

# %%
# Adding L2 regularization

from keras import regularizers

network = models.Sequential()

network.add(layers.Dense(512, kernel_regularizer=regularizers.l2(0.001), activation='relu', input_shape=(28 * 28,)))
network.add(layers.Dense(10, activation='softmax'))

network.compile(optimizer='rmsprop',loss='categorical_crossentropy',metrics=['accuracy'])
history2 = network.fit(train_images, train_labels, epochs=25, batch_size=128, validation_data=(val_images, val_labels))
# Out:
# Train on 45000 samples, validate on 15000 samples
# Epoch 1/25
# 45000/45000 [==============================] - 4s 97us/step - loss: 0.5405 - acc: 0.9112 - val_loss: 0.3512 - val_acc: 0.9388
# Epoch 2/25
# 45000/45000 [==============================] - 4s 87us/step - loss: 0.2748 - acc: 0.9523 - val_loss: 0.2834 - val_acc: 0.9405
# Epoch 3/25
# 45000/45000 [==============================] - 4s 88us/step - loss: 0.2176 - acc: 0.9608 - val_loss: 0.2067 - val_acc: 0.9636
# Epoch 4/25
# 45000/45000 [==============================] - 4s 88us/step - loss: 0.1912 - acc: 0.9662 - val_loss: 0.1849 - val_acc: 0.9663
# Epoch 5/25
# 45000/45000 [==============================] - 4s 89us/step - loss: 0.1768 - acc: 0.9680 - val_loss: 0.1955 - val_acc: 0.9634
# Epoch 6/25
# 45000/45000 [==============================] - 4s 88us/step - loss: 0.1661 - acc: 0.9711 - val_loss: 0.2058 - val_acc: 0.9576
# Epoch 7/25
# ...

# %%
epochs = range(1, len(history1.history['acc']) + 1)

plt.plot(epochs, history2.history['loss'], 'r', linestyle='-', label='L2 reg')
plt.plot(epochs, history2.history['val_loss'], 'r', linestyle='--')

plt.title('Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

# %%
# Adding dropout

network = models.Sequential()

network.add(layers.Dense(512, activation='relu', input_shape=(28 * 28,)))
network.add(layers.Dropout(0.5))
network.add(layers.Dense(10, activation='softmax'))

network.compile(optimizer='rmsprop',loss='categorical_crossentropy',metrics=['accuracy'])
history3 = network.fit(train_images, train_labels, epochs=25, batch_size=128, validation_data=(val_images, val_labels))
# Out:
# WARNING:tensorflow:From /Users/rudinakaprata/Documents/Aldo/ML_Stanford/venv_ML/lib/python2.7/site-packages/keras/backend/tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# Train on 45000 samples, validate on 15000 samples
# Epoch 1/25
# 45000/45000 [==============================] - 4s 96us/step - loss: 0.3592 - acc: 0.8940 - val_loss: 0.1848 - val_acc: 0.9456
# Epoch 2/25
# 45000/45000 [==============================] - 4s 82us/step - loss: 0.1747 - acc: 0.9490 - val_loss: 0.1383 - val_acc: 0.9587
# Epoch 3/25
# 45000/45000 [==============================] - 4s 82us/step - loss: 0.1339 - acc: 0.9607 - val_loss: 0.1128 - val_acc: 0.9678
# Epoch 4/25
# ...

# %%
epochs = range(1, len(history1.history['acc']) + 1)

plt.plot(epochs, history3.history['loss'], 'g', linestyle='-', label='Dropout')
plt.plot(epochs, history3.history['val_loss'], 'g', linestyle='--')

plt.title('Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

# %%
# Compare the 3 models

epochs = range(1, len(history1.history['acc']) + 1)

plt.plot(epochs, history1.history['loss'], 'b', linestyle='-', label='Standard')
plt.plot(epochs, history1.history['val_loss'], 'b', linestyle='--')

plt.plot(epochs, history2.history['loss'], 'r', linestyle='-', label='L2 Reg')
plt.plot(epochs, history2.history['val_loss'], 'r', linestyle='--')

plt.plot(epochs, history3.history['loss'], 'g', linestyle='-', label='Dropout')
plt.plot(epochs, history3.history['val_loss'], 'g', linestyle='--')

plt.title('Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

# %%
# Standard: overfitting
# L2 Reg: higher loss but no overfitting
# Dropout: loss in between and overfitting starts later
